# %%
import sys
sys.path.append("../src")

import procesador_texto

text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

t_lineas, t_palabras, prom, lista_lineas, conteos = procesador_texto.analizar_zen(text)

# Imprimo los resultados con f-strings
print(f"Total de líneas: {t_lineas}")
print(f"Total de palabras: {t_palabras}")
print(f"Promedio de palabras por línea: {prom:.2f}")

print(f"\nLíneas por encima del promedio ({prom:.2f} palabras):")
for i in range(len(lista_lineas)):
    if conteos[i] > prom:
        print(f' - "{lista_lineas[i]}" ({conteos[i]} palabras)')
# Out:
# Total de líneas: 19
# Total de palabras: 137
# Promedio de palabras por línea: 7.21
#
# Líneas por encima del promedio (7.21 palabras):
#  - "Special cases aren't special enough to break the rules." (9 palabras)
#  - "In the face of ambiguity, refuse the temptation to guess." (10 palabras)
#  - "There should be one-- and preferably only one --obvious way to do it." (13 palabras)
#  - "Although that way may not be obvious at first unless you're Dutch." (12 palabras)
#  - "Although never is often better than *right* now." (8 palabras)
#  - "If the implementation is hard to explain, it's a bad idea." (11 palabras)
#  - "If the implementation is easy to explain, it may be a good idea." (13 palabras)
#  - "Namespaces are one honking great idea -- let's do more of those!" (12 palabras)

# %%
import sys
sys.path.append("../src")

import musica

playlist = [
    {"title": "Bohemian Rhapsody", "duration": "5:55"},
    {"title": "Hotel California", "duration": "6:30"},
    {"title": "Stairway to Heaven", "duration": "8:02"},
    {"title": "Imagine", "duration": "3:07"},
    {"title": "Smells Like Teen Spirit", "duration": "5:01"},
    {"title": "Billie Jean", "duration": "4:54"},
    {"title": "Hey Jude", "duration": "7:11"},
    {"title": "Like a Rolling Stone", "duration": "6:13"},
]
duracion_total, cancion_larga, cancion_corta = musica.procesar_playlist(playlist)

print(f"Duración total de la playlist: {duracion_total}")
print(f"Canción más larga: {cancion_larga['title']} ({cancion_larga['duration']})")
print(f"Canción más corta: {cancion_corta['title']} ({cancion_corta['duration']})")
# Out:
# Duración total de la playlist: 46m 53s
# Canción más larga: Stairway to Heaven (8:02)
# Canción más corta: Imagine (3:07)

# %%
import filtro_spoiler
review = """La película sigue a un grupo de astronautas que
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo
a través
de tormentas solares y fallos en el sistema de navegación. Al
llegar
a Marte descubren que la base está abandonada y los
suministros
destruidos. Torres decide sacrificar la nave nodriza para
salvar
al equipo y logran volver a la Tierra en una cápsula de
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje
secreto."""
entrada_usuario = input("Ingrese las palabras que considere spoiler (separadas por coma): ")
lista_a_censurar = entrada_usuario.split(",")
print(filtro_spoiler.palabras_filtradas(review,lista_a_censurar))
# Out:
# La película sigue a un grupo de astronautas que
# viajan a *****
# en una misión de rescate. El capitán ****** lidera al equipo
# a través
# de tormentas solares y fallos en el sistema de navegación. Al
# llegar
# a ***** descubren que la base está abandonada y los
# suministros
# destruidos. ****** decide sacrificar la nave nodriza para
# salvar
# al equipo y logran volver a la Tierra en una cápsula de
# emergencia.
# El final revela que ****** sobrevivió gracias a un pasaje
# secreto.

# %%
import validar_mail
mail=input("ingrese su mail:")
if validar_mail.validacion(mail):
    print(f"El mail '{mail}' es válido.")
else:
    print(f"El mail '{mail}' NO es válido.")
# Out:
# El mail 'p.com' NO es válido.

# %%
import costo_envio
peso=float(input("Ingrese el peso del paquete (kg):"))
zona=input("Ingrese la zona de destino (local/regional/nacional")
costo = costo_envio.peso_zona(peso, zona)
if costo==False:
    print("Zona no válida. Las zonas disponibles son: local, regional, nacional.")
else:
    print(f"Costo de envío: ${costo:.2f}")
# Out:
# Costo de envío: $5000.00

# %%
import cifrado_cesar
texto_original = input("Ingrese un mensaje: ")
n = int(input("Ingrese el desplazamiento (número entero): "))    
# 2. Cifrado
cifrado = cifrado_cesar.procesar_mensaje(texto_original, n)
print(f"Mensaje cifrado: {cifrado}")    
# 3. Descifrado (usamos el desplazamiento negativo)
descifrado = cifrado_cesar.procesar_mensaje(cifrado, -n)
print(f"Mensaje descifrado: {descifrado}")
# Out:
# Mensaje cifrado: Krod Pxqgr!
# Mensaje descifrado: Hola Mundo!

# %%
import alumnos
students = [
{"name": " Ana García ", "grade": "8", "status":
"aprobado"},
{"name": "pedro lópez", "grade": "4", "status":
"DESAPROBADO"},
{"name": "MARÍA FERNÁNDEZ", "grade": "10", "status":
"Aprobado"},
{"name": "ana garcía", "grade": "9", "status":
"aprobado"},
{"name": None, "grade": "7", "status": "aprobado"},
{"name": "Luis Martínez ", "grade": None, "status":
"aprobado"},
{"name": " carlos RUIZ", "grade": "6", "status":
"aprobado"},
{"name": "PEDRO LÓPEZ ", "grade": "3", "status":
"desaprobado"},
{"name": " ", "grade": "5", "status": "aprobado"},
{"name": "María Fernández", "grade": "7", "status":
"APROBADO"},
{"name": "Sofía Torres", "grade": "9", "status":
"Aprobado"},
{"name": " sofía torres ", "grade": "8", "status":
"aprobado"},
{"name": "Carlos Ruiz", "grade": "6", "status":
"APROBADO"},
{"name": "Roberto Díaz", "grade": "absent", "status":
"ausente"},
{"name": "roberto díaz", "grade": "", "status":
"Ausente"},
{"name": None, "grade": None, "status": None},
{"name": "Laura Méndez", "grade": "7", "status":
"aprobado"},
{"name": " laura méndez", "grade": "8", "status":
"Aprobado"},
{"name": "GABRIELA RÍOS", "grade": "5", "status":
"aprobado"},
{"name": "gabriela ríos ", "grade": "4", "status":
"Desaprobado"},
]
resultado=alumnos.limpiar_registros(students)
for nombre, datos in resultado:
    #le pido el formato a la ia para imprimir parecido
    print(f"{nombre:<20} {datos['nota']:<5} {datos['estado']:<12}")
print(f"Total de alumnos válidos: {len(resultado)}")
# Out:
# Ana García           9     Aprobado
# Carlos Ruiz          6     Aprobado
# Gabriela Ríos        5     Aprobado
# Laura Méndez         8     Aprobado
# María Fernández      10    Aprobado
# Pedro López          4     Desaprobado
# Sofía Torres         9     Aprobado
# Total de alumnos válidos: 7
