# %%
import sys
sys.path.append("../src")

import procesador_texto

text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

t_lineas, t_palabras, prom, lista_lineas, conteos = procesador_texto.analizar_zen(text)

# Imprimo los resultados con f-strings
print(f"Total de líneas: {t_lineas}")
print(f"Total de palabras: {t_palabras}")
print(f"Promedio de palabras por línea: {prom:.2f}")

print(f"\nLíneas por encima del promedio ({prom:.2f} palabras):")
for i in range(len(lista_lineas)):
    if conteos[i] > prom:
        print(f' - "{lista_lineas[i]}" ({conteos[i]} palabras)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 26
#      22 If the implementation is hard to explain, it's a bad idea.
#      23 If the implementation is easy to explain, it may be a good idea.
#      24 Namespaces are one honking great idea -- let's do more of those!"""
#      25
# ---> 26 t_lineas, t_palabras, prom, lista_lineas, conteos = procesador_texto.analizar_zenanalizar_zen(text)
#      27
#      28 # Imprimo los resultados con f-strings
#      29 print(f"Total de líneas: {t_lineas}")
#
# AttributeError: module 'procesador_texto' has no attribute 'analizar_zenanalizar_zen'
